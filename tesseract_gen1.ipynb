# %% [markdown]
# <a href="https://colab.research.google.com/github/tesseractinhand2-dev/learn/blob/main/tesseract_gen1.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>
